# %%
# Cell 1: Setup and imports
import sys
import os
from pathlib import Path
import numpy as np
import matplotlib.pyplot as plt

# Add parent directory to path
sys.path.append(os.path.dirname(os.path.dirname(os.path.abspath(""))))

from machine_learning.utils.image_processing import (
    load_image,
    project_solar_image,
    project_visible_hemisphere
)

# Set up paths
BASE_DIR = Path("C:/Projects/SolarSpotting-App/machine_learning")
RAW_DIR = BASE_DIR / "storage" / "raw"
PROJECTED_DIR = BASE_DIR / "storage" / "projected"

# Cell 2: List available images
print("Available images in raw storage:")
for img_path in RAW_DIR.glob("*.jpg"):
    print(f"  - {img_path.name}")

# Cell 3: Project a 4K image
image_path4k = RAW_DIR / "20141231_000000_Ic_flat_4k.jpg"
image_path512 = RAW_DIR / "20141231_000000_Ic_flat_512.jpg"

# Full Carrington projection
print("Creating Carrington projection (4K)...")
projected_map, output_path = project_solar_image(image_path4k, resolution="4k")
print(f"Projection complete!")

# Cell 4: Project the same image to 512 resolution
print("\nCreating Carrington projection (512)...")
projected_map_512, output_path_512 = project_solar_image(image_path512, resolution="512")
print(f"Projection complete!")

# Cell 5: Create hemisphere projection
print("\nCreating hemisphere projection (4K)...")
hemisphere_img, hemisphere_path = project_visible_hemisphere(image_path4k, resolution="4k")

print("\nCreating hemisphere projection (512)...")
hemisphere_img_512, hemisphere_path_512 = project_visible_hemisphere(image_path512, resolution="512")

# Cell 6: Display results
# Load the original image for comparison
original_img4k = load_image(image_path4k)

plt.figure(figsize=(20, 8))

plt.subplot(1, 3, 1)
plt.imshow(original_img4k, cmap='gray')
plt.title('Original Solar Disk')
plt.axis('off')

plt.subplot(1, 3, 2)
projected_map.plot()
plt.title('Carrington Projection')

plt.subplot(1, 3, 3)
plt.imshow(hemisphere_img, cmap='gray')
plt.title('Hemisphere Projection')
plt.axis('off')

plt.tight_layout()
plt.show()

# Cell 7: Check output files
print("Files created:")
for resolution in ["4k", "512"]:
    res_dir = PROJECTED_DIR / resolution
    if res_dir.exists():
        print(f"\n{resolution} resolution:")
        for file in res_dir.glob("*"):
            print(f"  - {file.name} ({file.stat().st_size / 1024:.1f} KB)")
# Out:
# WARNING: SunpyUserWarning: Importing sunpy.map without its extra dependencies may result in errors.
# The following packages are not installed:
# ['mpl-animators>=1.0.0']
# To install sunpy with these dependencies use `pip install sunpy[map]` or `pip install sunpy[all]` for all extras.
# If you installed sunpy via conda, please report this to the community channel: https://matrix.to/#/#sunpy:openastronomy.org [sunpy.util.sysinfo]
# WARNING: SunpyUserWarning: Importing sunpy.visualization without its extra dependencies may result in errors.
# The following packages are not installed:
# ['mpl-animators>=1.0.0']
# To install sunpy with these dependencies use `pip install sunpy[visualization]` or `pip install sunpy[all]` for all extras.
# If you installed sunpy via conda, please report this to the community channel: https://matrix.to/#/#sunpy:openastronomy.org [sunpy.util.sysinfo]
# Available images in raw storage:
#   - 20141231_000000_Ic_flat_4k.jpg
#   - 20141231_000000_Ic_flat_512.jpg
#   - 20150102_000000_Ic_flat_4k.jpg
#   - 20150102_000000_Ic_flat_512.jpg
# Creating Carrington projection (4K)...
# ---------------------------------------------------------------------------
# ConvertError                              Traceback (most recent call last)
# Cell In[1], line 33
#      31 # Full Carrington projection
#      32 print("Creating Carrington projection (4K)...")
# ---> 33 projected_map, output_path = project_solar_image(image_path4k, resolution="4k")
#      34 print(f"Projection complete!")
#      36 # Cell 4: Project the same image to 512 resolution
#
# File C:\Projects\SolarSpotting-App\machine_learning\utils\image_processing.py:274, in project_solar_image(image_path, output_dir, resolution, save)
#     272 with warnings.catch_warnings():
#     273     warnings.simplefilter("ignore")
# --> 274     projected_data, footprint = reproject_adaptive(
#     275         (solar_map.data, solar_map.wcs),
#     276         WCS(out_header),
#     277         output_size,
#     278         conserve_flux=True
#     279     )
#     281 # Replace NaN values with 0
#     282 projected_data = np.nan_to_num(projected_data, nan=0.0)
#
# File C:\Projects\SolarSpotting-App\machine_learning\venv\Lib\site-packages\reproject\adaptive\high_level.py:233, in reproject_adaptive(input_data, output_projection, shape_out, hdu_in, center_jacobian, despike_jacobian, roundtrip_coords, conserve_flux, kernel, kernel_width, sample_region_width, boundary_mode, boundary_fill_value, boundary_ignore_threshold, x_cyclic, y_cyclic, bad_value_mode, bad_fill_value, output_array, output_footprint, return_footprint, block_size, parallel, return_type)
#     228 array_in, wcs_in = parse_input_data(input_data, hdu_in=hdu_in)
#     229 wcs_out, shape_out = parse_output_projection(
#     230     output_projection, shape_in=array_in.shape, shape_out=shape_out
#     231 )
# --> 233 return _reproject_dispatcher(
#     234     _reproject_adaptive_2d,
#     235     array_in=array_in,
#     236     wcs_in=wcs_in,
#     237     wcs_out=wcs_out,
#     238     shape_out=shape_out,
#     239     array_out=output_array,
#     240     parallel=parallel,
#     241     block_size=block_size,
#     242     return_footprint=return_footprint,
#     243     output_footprint=output_footprint,
#     244     reproject_func_kwargs=dict(
#     245         center_jacobian=center_jacobian,
#     246         despike_jacobian=despike_jacobian,
#     247         roundtrip_coords=roundtrip_coords,
#     248         conserve_flux=conserve_flux,
#     249         kernel=kernel,
#     250         kernel_width=kernel_width,
#     251         sample_region_width=sample_region_width,
#     252         boundary_mode=boundary_mode,
#     253         boundary_fill_value=boundary_fill_value,
#     254         boundary_ignore_threshold=boundary_ignore_threshold,
#     255         x_cyclic=x_cyclic,
#     256         y_cyclic=y_cyclic,
#     257         bad_value_mode=bad_value_mode,
#     258         bad_fill_value=bad_fill_value,
#     259     ),
#     260     return_type=return_type,
#     261 )
#
# File C:\Projects\SolarSpotting-App\machine_learning\venv\Lib\site-packages\reproject\common.py:170, in _reproject_dispatcher(reproject_func, array_in, wcs_in, shape_out, wcs_out, block_size, array_out, return_footprint, output_footprint, parallel, reproject_func_kwargs, return_type)
#     167 logger.info(f"Calling {reproject_func.__name__} in non-dask mode")
#     169 try:
# --> 170     return reproject_func(
#     171         array_in,
#     172         wcs_in,
#     173         wcs_out,
#     174         shape_out=shape_out,
#     175         array_out=array_out,
#     176         return_footprint=return_footprint,
#     177         output_footprint=output_footprint,
#     178         **reproject_func_kwargs,
#     179     )
#     180 finally:
#     181     # Clean up reference to numpy memmap
#     182     array_in = None
#
# File C:\Projects\SolarSpotting-App\machine_learning\venv\Lib\site-packages\reproject\adaptive\core.py:160, in _reproject_adaptive_2d(array, wcs_in, wcs_out, shape_out, array_out, output_footprint, return_footprint, center_jacobian, despike_jacobian, roundtrip_coords, conserve_flux, kernel, kernel_width, sample_region_width, boundary_mode, boundary_fill_value, boundary_ignore_threshold, x_cyclic, y_cyclic, bad_value_mode, bad_fill_value)
#     157     array_out = array_out.reshape((-1, *array_out.shape[-wcs_out.low_level_wcs.pixel_n_dim :]))
#     159 transformer = CoordinateTransformer(wcs_in, wcs_out, roundtrip_coords)
# --> 160 map_coordinates(
#     161     array_in,
#     162     array_out,
#     163     transformer,
#     164     out_of_range_nan=True,
#     165     center_jacobian=center_jacobian,
#     166     despiked_jacobian=despike_jacobian,
#     167     conserve_flux=conserve_flux,
#     168     kernel=kernel,
#     169     kernel_width=kernel_width,
#     170     sample_region_width=sample_region_width,
#     171     boundary_mode=boundary_mode,
#     172     boundary_fill_value=boundary_fill_value,
#     173     boundary_ignore_threshold=boundary_ignore_threshold,
#     174     x_cyclic=x_cyclic,
#     175     y_cyclic=y_cyclic,
#     176     bad_value_mode=bad_value_mode,
#     177     bad_fill_value=bad_fill_value,
#     178 )
#     180 array_out.shape = shape_out
#     182 if return_footprint:
#
# File reproject\\adaptive\\deforest.pyx:431, in reproject.adaptive.deforest.map_coordinates()
#
# File C:\Projects\SolarSpotting-App\machine_learning\venv\Lib\site-packages\reproject\adaptive\core.py:21, in CoordinateTransformer.__call__(self, pixel_out)
#      19 pixel_out = pixel_out[:, :, 0], pixel_out[:, :, 1]
#      20 if self.roundtrip_coords:
# ---> 21     pixel_in = pixel_to_pixel_with_roundtrip(self.wcs_out, self.wcs_in, *pixel_out)
#      22 else:
#      23     pixel_in = pixel_to_pixel(self.wcs_out, self.wcs_in, *pixel_out)
#
# File C:\Projects\SolarSpotting-App\machine_learning\venv\Lib\site-packages\reproject\wcs_utils.py:29, in pixel_to_pixel_with_roundtrip(wcs1, wcs2, *inputs)
#      28 def pixel_to_pixel_with_roundtrip(wcs1, wcs2, *inputs):
# ---> 29     outputs = pixel_to_pixel(wcs1, wcs2, *inputs)
#      31     # Now convert back to check that coordinates round-trip, if not then set to NaN
#      32     inputs_check = pixel_to_pixel(wcs2, wcs1, *outputs)
#
# File C:\Projects\SolarSpotting-App\machine_learning\venv\Lib\site-packages\astropy\wcs\utils.py:937, in pixel_to_pixel(wcs_in, wcs_out, *inputs)
#     934 if not isinstance(world_outputs, (tuple, list)):
#     935     world_outputs = (world_outputs,)
# --> 937 pixel_outputs = wcs_out.world_to_pixel(*world_outputs)
#     939 if wcs_out.pixel_n_dim == 1:
#     940     pixel_outputs = (pixel_outputs,)
#
# File C:\Projects\SolarSpotting-App\machine_learning\venv\Lib\site-packages\astropy\wcs\wcsapi\high_level_api.py:352, in HighLevelWCSMixin.world_to_pixel(self, *world_objects)
#     351 def world_to_pixel(self, *world_objects):
# --> 352     world_values = high_level_objects_to_values(
#     353         *world_objects, low_level_wcs=self.low_level_wcs
#     354     )
#     356     # Finally we convert to pixel coordinates
#     357     pixel_values = self.low_level_wcs.world_to_pixel_values(*world_values)
#
# File C:\Projects\SolarSpotting-App\machine_learning\venv\Lib\site-packages\astropy\wcs\wcsapi\high_level_api.py:212, in high_level_objects_to_values(low_level_wcs, *world_objects)
#     210 if isinstance(world_by_key[key], SkyCoord):
#     211     if "frame" in kwargs:
# --> 212         objects[key] = world_by_key[key].transform_to(kwargs["frame"])
#     213     else:
#     214         objects[key] = world_by_key[key]
#
# File C:\Projects\SolarSpotting-App\machine_learning\venv\Lib\site-packages\astropy\coordinates\sky_coordinate.py:555, in SkyCoord.transform_to(self, frame, merge_attributes)
#     551 generic_frame = GenericFrame(frame_kwargs)
#     553 # Do the transformation, returning a coordinate frame of the desired
#     554 # final type (not generic).
# --> 555 new_coord = trans(self.frame, generic_frame)
#     557 # Finally make the new SkyCoord object from the `new_coord` and
#     558 # remaining frame_kwargs that are not frame_attributes in `new_coord`.
#     559 for attr in set(new_coord.frame_attributes) & set(frame_kwargs.keys()):
#
# File C:\Projects\SolarSpotting-App\machine_learning\venv\Lib\site-packages\astropy\coordinates\transformations\composite.py:113, in CompositeTransform.__call__(self, fromcoord, toframe)
#     110             frattrs[inter_frame_attr_nm] = attr
#     112     curr_toframe = t.tosys(**frattrs)
# --> 113     curr_coord = t(curr_coord, curr_toframe)
#     115 # this is safe even in the case where self.transforms is empty, because
#     116 # coordinate objects are immutable, so copying is not needed
#     117 return curr_coord
#
# File C:\Projects\SolarSpotting-App\machine_learning\venv\Lib\site-packages\astropy\coordinates\transformations\function.py:175, in FunctionTransformWithFiniteDifference.__call__(self, fromcoord, toframe)
#     173 supcall = self.func
#     174 if not fromcoord.data.differentials:
# --> 175     return supcall(fromcoord, toframe)
#     176 # this is the finite difference case
#     178 if callable(self.finite_difference_dt):
#
# File C:\Projects\SolarSpotting-App\machine_learning\venv\Lib\site-packages\sunpy\coordinates\_transformations.py:256, in _transformation_debug.<locals>.decorator.<locals>.wrapped_func(*args, **kwargs)
#     253     # Increment the layer level to increase the indentation for nested transformations
#     254     _layer_level += 1
# --> 256 result = func(*args, **kwargs)
#     258 if debug_output:
#     259     # Decrement the layer level
#     260     _layer_level -= 1
#
# File C:\Projects\SolarSpotting-App\machine_learning\venv\Lib\site-packages\sunpy\coordinates\_transformations.py:404, in hgc_to_hgs(hgccoord, hgsframe)
#     397 @frame_transform_graph.transform(FunctionTransformWithFiniteDifference,
#     398                                  HeliographicCarrington, HeliographicStonyhurst)
#     399 @_transformation_debug("HGC->HGS")
#     400 def hgc_to_hgs(hgccoord, hgsframe):
#     401     """
#     402     Convert from Heliographic Carrington to Heliographic Stonyhurst.
#     403     """
# --> 404     _check_observer_defined(hgccoord)
#     406     hgccoord = hgccoord.make_3d()
#     408     if isinstance(hgccoord.observer, str) and hgccoord.observer == "self":
#
# File C:\Projects\SolarSpotting-App\machine_learning\venv\Lib\site-packages\sunpy\coordinates\_transformations.py:306, in _check_observer_defined(frame)
#     304 def _check_observer_defined(frame):
#     305     if frame.observer is None:
# --> 306         raise ConvertError("This transformation cannot be performed because the "
#     307                            f"{frame.__class__.__name__} frame has observer=None.")
#     308     elif isinstance(frame.observer, str):
#     309         if frame.observer != "self":
#
# ConvertError: This transformation cannot be performed because the HeliographicCarrington frame has observer=None.
